# %% [markdown]
# Instructions for using the deployment code:
# These codes allow us to use all the created models, and this specific code allows access to the individual models in the first group.
# Since you need to access the models, scalers, and CSV files, you cannot simply run this code from the location shared with me, as it will be impossible to access the models and files because the path simply does not exist.
#
# Therefore, the instructions to use this code will depend on your needs.
#
# The simplest way to run the code and use it to forecast irradiance is to go to the folder: 3) DeliveredProducts (End of Project), click on the three dots, click on Organize, click on Add shortcut, and finally select My Drive, which allows you to create a copy on your personal drive. Once this process is complete, the rest of the code is already adapted to run directly and without any issues. Therefore, if you want to forecast a day different from the test day, simply upload the CSV file to the drive (using the same format as the test CSV) in the same location as the Deployment codes. It's important to note that the required columns in the CSV file are the time column, the five sensors, the four columns for albedo, temperature, relative humidity, hourly sines and cosines, and daily sines and cosines. The remaining columns are optional. Furthermore, all the paths are already adapted to run the code with these instructions. Of course, you mustn't forget to define the parameters so the code can identify the model being used; incorrect parameter configuration can lead to errors.
#
# If the code needs to be used differently than described above, remember that the Models and Scalers folders are essential for the code to run correctly, as is the test file. Finally, you can also change the paths described in the code to make the forecasting process more automated. Just remember that if you don't follow the previous steps, you'll need to change those paths in the code.

# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns
from tensorflow import keras
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import r2_score
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Concatenate

# %% [markdown]
# Connection to drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Getting the dataframe from the drive

# %%
route_df='/content/drive/MyDrive/3) ProductosEntregados (Fin de proyecto)/Anexos/Deployment_codes/df_trial.csv'

# %%
df_try=pd.read_csv(route_df)
df_try
# Out:
#                     Time  Front POA1 (W/m2)  Front POA2 (W/m2)  Rear 1 (W/m2)  \
# 0    2025-05-08 00:00:00                0.0                0.0            0.0
# 1    2025-05-08 00:15:00                0.0                0.0            0.0
# 2    2025-05-08 00:30:00                0.0                0.0            0.0
# 3    2025-05-08 00:45:00                0.0                0.0            0.0
# 4    2025-05-08 01:00:00                0.0                0.0            0.0
# ..                   ...                ...                ...            ...
# 379  2025-05-11 22:45:00                0.0                0.0            0.0
# 380  2025-05-11 23:00:00                0.0                0.0            0.0
# 381  2025-05-11 23:15:00                0.0                0.0            0.0
# 382  2025-05-11 23:30:00                0.0                0.0            0.0
# 383  2025-05-11 23:45:00                0.0                0.0            0.0
#
# ...

# %% [markdown]
# Features of initial df

# %%
df_try.dtypes
# Out:
# Time                       object
# Front POA1 (W/m2)         float64
# Front POA2 (W/m2)         float64
# Rear 1 (W/m2)             float64
# Rear 2 (W/m2)             float64
# Rear 3 (W/m2)             float64
# G                         float64
# W                         float64
# B                         float64
# S                         float64
# Temperature C             float64
# Specific Humidity g/kg    float64
# Precipitation mm/hour     float64
# Relative Humidity %       float64
# tcc                       float64
# tclw                      float64
# sin_h                     float64
# cos_h                     float64
# sin_doy                   float64
# cos_doy                   float64
# dtype: object

# %%
df_try['Time']=pd.to_datetime(df_try['Time'],format='%Y-%m-%d %H:%M:%S')

# %% [markdown]
# Define seed

# %%
import os
import random
np.random.seed(42)
tf.random.set_seed(42)
random.seed(42)
os.environ['PYTHONHASHSEED']=str(42)

# %% [markdown]
# Define parameters

# %%
n_exo_var=4  #[2,3,4,5],
#2=[T,relative_humidity],
#3=[T,relative_humidity,tcc],
#4=[T,relative_humidity, tcc ,precipitation]
#5=[T,relative_humidity, tcc, precipitation, specific humidity]
model='CNNLSTM' #['TCN','CNNLSTM','CNNGRU']
scaler='MMS' #['RS','MMS']
#RS: Robust scaler, MMS: MinMaxScaler
retrain=True #[True, False]
win_size=96 #[4,8,12,16,20,24,....,96,...192,...]
#It is the window that you want to predict, have in mind that t=15min, so win_size=4 means 1 hour
obs_window=384 #[96,192,288,384,480,576,672,...]
#It is the information of the past that you are using to predict
#obs_window=96,192,288, means 1 day, 2 days and 3 days respectively
gap_setting=0 #[96,192,288]
#it is the space (gap) between the last data and the start of horizon
surface_tomorrow=np.array([0,1,0,0]).reshape(1,4) #[G,W,B,S]

# %% [markdown]
# Implement Scaler

# %%
import joblib

if scaler=='RS':

  scaler_POA1=joblib.load('/content/drive/MyDrive/3) ProductosEntregados (Fin de proyecto)/Anexos/Scalers/scaler_POA1_RS_g2.pkl')
  scaler_POA2=joblib.load('/content/drive/MyDrive/3) ProductosEntregados (Fin de proyecto)/Anexos/Scalers/scaler_POA2_RS_g2.pkl')
  scaler_Rear1=joblib.load('/content/drive/MyDrive/3) ProductosEntregados (Fin de proyecto)/Anexos/Scalers/scaler_Rear1_RS_g2.pkl')
  scaler_Rear2=joblib.load('/content/drive/MyDrive/3) ProductosEntregados (Fin de proyecto)/Anexos/Scalers/scaler_Rear2_RS_g2.pkl')
  scaler_Rear3=joblib.load('/content/drive/MyDrive/3) ProductosEntregados (Fin de proyecto)/Anexos/Scalers/scaler_Rear3_RS_g2.pkl')

  scaler_Temp=joblib.load('/content/drive/MyDrive/3) ProductosEntregados (Fin de proyecto)/Anexos/Scalers/scaler_Temp_RS_g2.pkl')
  scaler_Hum=joblib.load('/content/drive/MyDrive/3) ProductosEntregados (Fin de proyecto)/Anexos/Scalers/scaler_Hum_RS_g2.pkl')

  if n_exo_var==4:
    scaler_Prep=joblib.load('/content/drive/MyDrive/3) ProductosEntregados (Fin de proyecto)/Anexos/Scalers/scaler_Prep_RS_g2.pkl')

  if n_exo_var==5:
    scaler_Prep=joblib.load('/content/drive/MyDrive/3) ProductosEntregados (Fin de proyecto)/Anexos/Scalers/scaler_Prep_RS_g2.pkl')
    scaler_esp=joblib.load('/content/drive/MyDrive/3) ProductosEntregados (Fin de proyecto)/Anexos/Scalers/scaler_esp_RS_g2.pkl')

elif scaler=='MMS':
  scaler_POA1=joblib.load('/content/drive/MyDrive/3) ProductosEntregados (Fin de proyecto)/Anexos/Scalers/scaler_POA1_MMS_g2.pkl')
  scaler_POA2=joblib.load('/content/drive/MyDrive/3) ProductosEntregados (Fin de proyecto)/Anexos/Scalers/scaler_POA2_MMS_g2.pkl')
  scaler_Rear1=joblib.load('/content/drive/MyDrive/3) ProductosEntregados (Fin de proyecto)/Anexos/Scalers/scaler_Rear1_MMS_g2.pkl')
  scaler_Rear2=joblib.load('/content/drive/MyDrive/3) ProductosEntregados (Fin de proyecto)/Anexos/Scalers/scaler_Rear2_MMS_g2.pkl')
  scaler_Rear3=joblib.load('/content/drive/MyDrive/3) ProductosEntregados (Fin de proyecto)/Anexos/Scalers/scaler_Rear3_MMS_g2.pkl')

  scaler_Temp=joblib.load('/content/drive/MyDrive/3) ProductosEntregados (Fin de proyecto)/Anexos/Scalers/scaler_Temp_MMS_g2.pkl')
  scaler_Hum=joblib.load('/content/drive/MyDrive/3) ProductosEntregados (Fin de proyecto)/Anexos/Scalers/scaler_Hum_MMS_g2.pkl')

  if n_exo_var==4:
    scaler_Prep=joblib.load('/content/drive/MyDrive/3) ProductosEntregados (Fin de proyecto)/Anexos/Scalers/scaler_Prep_MMS_g2.pkl')

  if n_exo_var==5:
    scaler_Prep=joblib.load('/content/drive/MyDrive/3) ProductosEntregados (Fin de proyecto)/Anexos/Scalers/scaler_Prep_MMS_g2.pkl')
    scaler_esp=joblib.load('/content/drive/MyDrive/3) ProductosEntregados (Fin de proyecto)/Anexos/Scalers/scaler_esp_MMS_g2.pkl')
else:
  print('Scaler not implemented')

# %%
trial_poa1=df_try['Front POA1 (W/m2)'].values
trial_poa2=df_try['Front POA2 (W/m2)'].values
trial_rear1=df_try['Rear 1 (W/m2)'].values
trial_rear2=df_try['Rear 2 (W/m2)'].values
trial_rear3=df_try['Rear 3 (W/m2)'].values
trial_temp=df_try['Temperature C'].values
trial_hum=df_try['Relative Humidity %'].values
trial_tcc=df_try['tcc'].values
trial_prep=df_try['Precipitation mm/hour'].values
trial_esp=df_try['Specific Humidity g/kg'].values
trial_sin_h=df_try['sin_h'].values
trial_cos_h=df_try['cos_h'].values
trial_sin_doy=df_try['sin_doy'].values
trial_cos_doy=df_try['cos_doy'].values
trial_G=df_try['G'].values
trial_W=df_try['W'].values
trial_B=df_try['B'].values
trial_S=df_try['S'].values

POA1_test=np.zeros((trial_poa1.shape[0],n_exo_var+5))
POA2_test=np.zeros((trial_poa2.shape[0],n_exo_var+5))
Rear1_test=np.zeros((trial_rear1.shape[0],n_exo_var+9))
Rear2_test=np.zeros((trial_rear2.shape[0],n_exo_var+9))
Rear3_test=np.zeros((trial_rear3.shape[0],n_exo_var+9))

# %% [markdown]
# Transform with the scalers created

# %%
POA1_test[:,0]=(scaler_POA1.transform(trial_poa1.reshape(-1,1))).reshape(POA1_test.shape[0])

POA1_test[:,1]=(scaler_Temp.transform(trial_temp.reshape(-1,1))).reshape(POA1_test.shape[0])

POA1_test[:,2]=(scaler_Hum.transform(trial_hum.reshape(-1,1))).reshape(POA1_test.shape[0])

if n_exo_var==3:
  POA1_test[:,3]=trial_tcc/100

if n_exo_var==4:
  POA1_test[:,3]=trial_tcc/100
  POA1_test[:,4]=(scaler_Prep.transform(trial_prep.reshape(-1,1))).reshape(POA1_test.shape[0])
if n_exo_var==5:
  POA1_test[:,3]=trial_tcc/100
  POA1_test[:,4]=(scaler_Prep.transform(trial_prep.reshape(-1,1))).reshape(POA1_test.shape[0])
  POA1_test[:,5]=(scaler_esp.transform(trial_esp.reshape(-1,1))).reshape(POA1_test.shape[0])
POA1_test[:,n_exo_var+1]=trial_sin_h
POA1_test[:,n_exo_var+2]=trial_cos_h
POA1_test[:,n_exo_var+3]=trial_sin_doy
POA1_test[:,n_exo_var+4]=trial_cos_doy

# %%
POA2_test[:,0]=(scaler_POA2.transform(trial_poa2.reshape(-1,1))).reshape(POA2_test.shape[0])

POA2_test[:,1]=(scaler_Temp.transform(trial_temp.reshape(-1,1))).reshape(POA2_test.shape[0])
POA2_test[:,2]=(scaler_Hum.transform(trial_hum.reshape(-1,1))).reshape(POA2_test.shape[0])

if n_exo_var==3:
  POA2_test[:,3]=trial_tcc/100
if n_exo_var==4:
  POA2_test[:,3]=trial_tcc/100
  POA2_test[:,4]=(scaler_Prep.transform(trial_prep.reshape(-1,1))).reshape(POA2_test.shape[0])
if n_exo_var==5:
  POA2_test[:,3]=trial_tcc/100
  POA2_test[:,4]=(scaler_Prep.transform(trial_prep.reshape(-1,1))).reshape(POA2_test.shape[0])
  POA2_test[:,5]=(scaler_esp.transform(trial_esp.reshape(-1,1))).reshape(POA2_test.shape[0])
POA2_test[:,n_exo_var+1]=trial_sin_h
POA2_test[:,n_exo_var+2]=trial_cos_h
POA2_test[:,n_exo_var+3]=trial_sin_doy
POA2_test[:,n_exo_var+4]=trial_cos_doy

# %%
Rear1_test[:,0]=(scaler_Rear1.transform(trial_rear1.reshape(-1,1))).reshape(Rear1_test.shape[0])

Rear1_test[:,1]=(scaler_Temp.transform(trial_temp.reshape(-1,1))).reshape(Rear1_test.shape[0])
Rear1_test[:,2]=(scaler_Hum.transform(trial_hum.reshape(-1,1))).reshape(Rear1_test.shape[0])

if n_exo_var==3:
  Rear1_test[:,3]=trial_tcc/100
if n_exo_var==4:
  Rear1_test[:,3]=trial_tcc/100
  Rear1_test[:,4]=(scaler_Prep.transform(trial_prep.reshape(-1,1))).reshape(Rear1_test.shape[0])
if n_exo_var==5:
  Rear1_test[:,3]=trial_tcc/100
  Rear1_test[:,4]=(scaler_Prep.transform(trial_prep.reshape(-1,1))).reshape(Rear1_test.shape[0])
  Rear1_test[:,5]=(scaler_esp.transform(trial_esp.reshape(-1,1))).reshape(Rear1_test.shape[0])

Rear1_test[:,n_exo_var+1]=trial_sin_h
Rear1_test[:,n_exo_var+2]=trial_cos_h
Rear1_test[:,n_exo_var+3]=trial_sin_doy
Rear1_test[:,n_exo_var+4]=trial_cos_doy
Rear1_test[:,n_exo_var+5]=trial_G
Rear1_test[:,n_exo_var+6]=trial_W
Rear1_test[:,n_exo_var+7]=trial_B
Rear1_test[:,n_exo_var+8]=trial_S

# %%
Rear2_test[:,0]=(scaler_Rear2.transform(trial_rear2.reshape(-1,1))).reshape(Rear2_test.shape[0])

Rear2_test[:,1]=(scaler_Temp.transform(trial_temp.reshape(-1,1))).reshape(Rear2_test.shape[0])
Rear2_test[:,2]=(scaler_Hum.transform(trial_hum.reshape(-1,1))).reshape(Rear2_test.shape[0])

if n_exo_var==3:
  Rear2_test[:,3]=trial_tcc/100
if n_exo_var==4:
  Rear2_test[:,3]=trial_tcc/100
  Rear2_test[:,4]=(scaler_Prep.transform(trial_prep.reshape(-1,1))).reshape(Rear2_test.shape[0])
if n_exo_var==5:
  Rear2_test[:,3]=trial_tcc/100
  Rear2_test[:,4]=(scaler_Prep.transform(trial_prep.reshape(-1,1))).reshape(Rear2_test.shape[0])
  Rear2_test[:,5]=(scaler_esp.transform(trial_esp.reshape(-1,1))).reshape(Rear2_test.shape[0])

Rear2_test[:,n_exo_var+1]=trial_sin_h
Rear2_test[:,n_exo_var+2]=trial_cos_h
Rear2_test[:,n_exo_var+3]=trial_sin_doy
Rear2_test[:,n_exo_var+4]=trial_cos_doy
Rear2_test[:,n_exo_var+5]=trial_G
Rear2_test[:,n_exo_var+6]=trial_W
Rear2_test[:,n_exo_var+7]=trial_B
Rear2_test[:,n_exo_var+8]=trial_S

# %%
Rear3_test[:,0]=(scaler_Rear3.transform(trial_rear3.reshape(-1,1))).reshape(Rear3_test.shape[0])

Rear3_test[:,1]=(scaler_Temp.transform(trial_temp.reshape(-1,1))).reshape(Rear3_test.shape[0])
Rear3_test[:,2]=(scaler_Hum.transform(trial_hum.reshape(-1,1))).reshape(Rear3_test.shape[0])

if n_exo_var==3:
  Rear3_test[:,3]=trial_tcc/100
if n_exo_var==4:
  Rear3_test[:,3]=trial_tcc/100
  Rear3_test[:,4]=(scaler_Prep.transform(trial_prep.reshape(-1,1))).reshape(Rear3_test.shape[0])
if n_exo_var==5:
  Rear3_test[:,3]=trial_tcc/100
  Rear3_test[:,4]=(scaler_Prep.transform(trial_prep.reshape(-1,1))).reshape(Rear3_test.shape[0])
  Rear3_test[:,5]=(scaler_esp.transform(trial_esp.reshape(-1,1))).reshape(Rear3_test.shape[0])

Rear3_test[:,n_exo_var+1]=trial_sin_h
Rear3_test[:,n_exo_var+2]=trial_cos_h
Rear3_test[:,n_exo_var+3]=trial_sin_doy
Rear3_test[:,n_exo_var+4]=trial_cos_doy
Rear3_test[:,n_exo_var+5]=trial_G
Rear3_test[:,n_exo_var+6]=trial_W
Rear3_test[:,n_exo_var+7]=trial_B
Rear3_test[:,n_exo_var+8]=trial_S

# %% [markdown]
# POA1

# %%
if scaler=='RS':
  num_scaler=2
elif scaler=='MMS':
  num_scaler=4
else:
  print('Scaler not implemented')

# %%
if retrain==True:
  model_selected=f'/content/drive/MyDrive/3) ProductosEntregados (Fin de proyecto)/Anexos/Models/models_{model}_{scaler}/model_{model}{num_scaler}_POA1_n{n_exo_var}_v2.keras'
else:
  model_selected=f'/content/drive/MyDrive/3) ProductosEntregados (Fin de proyecto)/Anexos/Models/models_{model}_{scaler}/model_{model}{num_scaler}_POA1_n{n_exo_var}.keras'

# %%
model1_POA1=keras.models.load_model(model_selected)

# %% [markdown]
# Prediction and evaluation

# %%
pred_POA1_p1=model1_POA1.predict(POA1_test.reshape(1,POA1_test.shape[0],POA1_test.shape[1]))
predict_POA1_p1=(scaler_POA1.inverse_transform(pred_POA1_p1.reshape(-1,1))).reshape(pred_POA1_p1.shape[0],pred_POA1_p1.shape[1])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step

# %%
plt.figure(figsize=(14,8))
plt.plot(predict_POA1_p1.reshape(-1,1),label='POA1',color='blue')

plt.title("Prediction")
plt.xlabel("Date")
plt.ylabel("W/m2")
plt.legend()
plt.show()

# %% [markdown]
# POA2

# %%
if retrain==True:
  model_selected2=f'/content/drive/MyDrive/3) ProductosEntregados (Fin de proyecto)/Anexos/Models/models_{model}_{scaler}/model_{model}{num_scaler}_POA2_n{n_exo_var}_v2.keras'
else:
  model_selected2=f'/content/drive/MyDrive/3) ProductosEntregados (Fin de proyecto)/Anexos/Models/models_{model}_{scaler}/model_{model}{num_scaler}_POA2_n{n_exo_var}.keras'

# %%
model1_POA2=keras.models.load_model(model_selected2)

# %% [markdown]
# Prediction and evaluation

# %%
pred_POA2_p1=model1_POA2.predict(POA2_test.reshape(1,POA2_test.shape[0],POA2_test.shape[1]))
predict_POA2_p1=(scaler_POA2.inverse_transform(pred_POA2_p1.reshape(-1,1))).reshape(pred_POA2_p1.shape[0],pred_POA2_p1.shape[1])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step

# %%
plt.figure(figsize=(14,8))
plt.plot(predict_POA2_p1.reshape(-1,1),label='POA2',color='blue')

plt.title("Prediction")
plt.xlabel("Date")
plt.ylabel("W/m2")
plt.legend()
plt.show()

# %% [markdown]
# REAR 1

# %%
if retrain==True:
  model_selected3=f'/content/drive/MyDrive/3) ProductosEntregados (Fin de proyecto)/Anexos/Models/models_{model}_{scaler}/model_{model}{num_scaler}_Rear1_n{n_exo_var}_v2.keras'
else:
  model_selected3=f'/content/drive/MyDrive/3) ProductosEntregados (Fin de proyecto)/Anexos/Models/models_{model}_{scaler}/model_{model}{num_scaler}_Rear1_n{n_exo_var}.keras'

# %%
model1_Rear1=keras.models.load_model(model_selected3)

# %% [markdown]
# Prediction and evaluation

# %%
pred_Rear1_p1=model1_Rear1.predict([Rear1_test.reshape(1,Rear1_test.shape[0],Rear1_test.shape[1]),surface_tomorrow])
predict_Rear1_p1=(scaler_Rear1.inverse_transform(pred_Rear1_p1.reshape(-1,1))).reshape(pred_Rear1_p1.shape[0],pred_Rear1_p1.shape[1])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step

# %%
plt.figure(figsize=(14,8))
plt.plot(predict_Rear1_p1.reshape(-1,1),label='Rear1',color='blue')

plt.title("Prediction")
plt.xlabel("Date")
plt.ylabel("W/m2")
plt.legend()
plt.show()

# %% [markdown]
# REAR 2

# %%
if retrain==True:
  model_selected4=f'/content/drive/MyDrive/3) ProductosEntregados (Fin de proyecto)/Anexos/Models/models_{model}_{scaler}/model_{model}{num_scaler}_Rear2_n{n_exo_var}_v2.keras'
else:
  model_selected4=f'/content/drive/MyDrive/3) ProductosEntregados (Fin de proyecto)/Anexos/Models/models_{model}_{scaler}/model_{model}{num_scaler}_Rear2_n{n_exo_var}.keras'

# %%
model1_Rear2=keras.models.load_model(model_selected4)

# %% [markdown]
# Prediction and evaluation

# %%
pred_Rear2_p1=model1_Rear2.predict([Rear2_test.reshape(1,Rear2_test.shape[0],Rear2_test.shape[1]),surface_tomorrow])
predict_Rear2_p1=(scaler_Rear2.inverse_transform(pred_Rear2_p1.reshape(-1,1))).reshape(pred_Rear2_p1.shape[0],pred_Rear2_p1.shape[1])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step

# %%
plt.figure(figsize=(14,8))
plt.plot(predict_Rear2_p1.reshape(-1,1),label='Rear2',color='blue')

plt.title("Prediction")
plt.xlabel("Date")
plt.ylabel("W/m2")
plt.legend()
plt.show()

# %% [markdown]
# REAR 3

# %%
if retrain==True:
  model_selected5=f'/content/drive/MyDrive/3) ProductosEntregados (Fin de proyecto)/Anexos/Models/models_{model}_{scaler}/model_{model}{num_scaler}_Rear3_n{n_exo_var}_v2.keras'
else:
  model_selected5=f'/content/drive/MyDrive/3) ProductosEntregados (Fin de proyecto)/Anexos/Models/models_{model}_{scaler}/model_{model}{num_scaler}_Rear3_n{n_exo_var}.keras'

# %%
model1_Rear3=keras.models.load_model(model_selected5)

# %% [markdown]
# Prediction and evaluation

# %%
pred_Rear3_p1=model1_Rear3.predict([Rear3_test.reshape(1,Rear3_test.shape[0],Rear3_test.shape[1]),surface_tomorrow])
predict_Rear3_p1=(scaler_Rear3.inverse_transform(pred_Rear3_p1.reshape(-1,1))).reshape(pred_Rear3_p1.shape[0],pred_Rear3_p1.shape[1])
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7b5e3b6f6fc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step

# %%
plt.figure(figsize=(14,8))
plt.plot(predict_Rear3_p1.reshape(-1,1),label='Rear3',color='blue')

plt.title("Prediction")
plt.xlabel("Date")
plt.ylabel("W/m2")
plt.legend()
plt.show()
